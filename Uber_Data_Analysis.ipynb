# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("bhanupratapbiswas/uber-data-analysis")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'uber-data-analysis' dataset.
# Path to dataset files: /kaggle/input/uber-data-analysis

# %%
import os

# Show all files in the downloaded dataset folder
print(os.listdir(path))
# Out:
# ['UberDataset.csv']

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Find the file name
files = os.listdir(path)
print(files)

# Load the CSV
df = pd.read_csv(os.path.join(path, files[0]))

# Display first 5 rows
df.head()
# Out:
# ['UberDataset.csv']
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# DATA PREPROCESSING

# %%
df['PURPOSE']=df['PURPOSE'].fillna('Missing')

# %%
df['START_DATE']=pd.to_datetime(df['START_DATE'],errors='coerce')
df['END_DATE']=pd.to_datetime(df['END_DATE'],errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime
df['dateof_start']=pd.DatetimeIndex(df['START_DATE']).date
df['timeof_start']=pd.DatetimeIndex(df['START_DATE']).hour

# %%
df.drop(columns=['date', 'time'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4606/1820156221.py in <cell line: 0>()
# ----> 1 df.drop(columns=['date', 'time'], inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.head(5)
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE dateof_start  timeof_start
# 0      Fort Pierce    5.1   Meal/Entertain   2016-01-01          21.0
# 1      Fort Pierce    5.0          Missing   2016-01-02           1.0
# 2      Fort Pierce    4.8  Errand/Supplies   2016-01-02          20.0
# 3      Fort Pierce    4.7          Meeting   2016-01-05          17.0
# 4  West Palm Beach   63.7   Customer Visit   2016-01-06          14.0

# %%
df['day-night']=pd.cut(x=df['timeof_start'],bins=[0,10,15,19,24],labels=['Morning','Afternoon','Evening','Night'])
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE dateof_start  timeof_start  \
# 0      Fort Pierce    5.1   Meal/Entertain   2016-01-01          21.0
# 1      Fort Pierce    5.0          Missing   2016-01-02           1.0
# 2      Fort Pierce    4.8  Errand/Supplies   2016-01-02          20.0
# 3      Fort Pierce    4.7          Meeting   2016-01-05          17.0
# 4  West Palm Beach   63.7   Customer Visit   2016-01-06          14.0
#
#    day-night
# 0      Night
# 1    Morning
# 2      Night
# 3    Evening
# 4  Afternoon

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (413, 10)

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.countplot(df['CATEGORY'])

plt.subplot(1,2,2)
sns.countplot(df['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %%
sns.countplot(df['day-night'])
# Out:
# <Axes: xlabel='count', ylabel='day-night'>

# %%
df['month'] = pd.to_datetime(df['START_DATE']).dt.month_name()
df['day'] = pd.to_datetime(df['START_DATE']).dt.day_name()
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE dateof_start  timeof_start  \
# 0      Fort Pierce    5.1   Meal/Entertain   2016-01-01          21.0
# 1      Fort Pierce    5.0          Missing   2016-01-02           1.0
# 2      Fort Pierce    4.8  Errand/Supplies   2016-01-02          20.0
# 3      Fort Pierce    4.7          Meeting   2016-01-05          17.0
# 4  West Palm Beach   63.7   Customer Visit   2016-01-06          14.0
#
#    day-night    month        day
# 0      Night  January     Friday
# 1    Morning  January   Saturday
# 2      Night  January   Saturday
# ...

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.countplot(df['month'])

plt.subplot(1,2,2)
sns.countplot(df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.boxplot(df['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(df[df['MILES']<100]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(df[df['MILES']<40]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.distplot(df[df['MILES']<40]['MILES'])
# Out:
# /tmp/ipykernel_4606/1171915261.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['MILES']<40]['MILES'])
# <Axes: xlabel='MILES', ylabel='Density'>
